# %%
from src.agent.meta import MetaAgent
from src.agent.cot import COTAgent
from src.agent.tool import ToolAgent
from src.agent.react import ReactAgent

# %% [markdown]
# ### Graphs of all agents

# %%
MetaAgent().plot_mermaid()

# %%
ReactAgent().plot_mermaid()

# %%
COTAgent().plot_mermaid()

# %%
ToolAgent().plot_mermaid()
